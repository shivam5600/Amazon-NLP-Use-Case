# %%
import pandas as pd
import numpy as np
import plotly.express as px
import re
import string

#warnings :)
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Roman Urdu DataSet.csv",header=None)
df.head()
# Out:
#                                                    0         1    2
# 0  Sai kha ya her kisi kay bus ki bat nhi hai lak...  Positive  NaN
# 1                                          sahi bt h  Positive  NaN
# 2                                        Kya bt hai,  Positive  NaN
# 3                                         Wah je wah  Positive  NaN
# 4                               Are wha kaya bat hai  Positive  NaN

# %%
df.columns
# Out:
# Int64Index([0, 1, 2], dtype='int64')

# %%
df.rename(columns={0:'statement',1:'review'},inplace=True)
df.drop(columns=2,inplace=True)
df.head()
# Out:
#                                            statement    review
# 0  Sai kha ya her kisi kay bus ki bat nhi hai lak...  Positive
# 1                                          sahi bt h  Positive
# 2                                        Kya bt hai,  Positive
# 3                                         Wah je wah  Positive
# 4                               Are wha kaya bat hai  Positive

# %%
df.shape
# Out:
# (20229, 2)

# %%
px.histogram(df,x='review')

# %%
df.review.value_counts()
# Out:
# Neutral     8929
# Positive    6013
# Negative    5286
# Neative        1
# Name: review, dtype: int64

# %%
df[df['review']=='Neative']
# Out:
#                                                statement   review
# 13277  product achi hai but wrong waist size send kar...  Neative

# %%
df['review'] = df['review'].replace(['Neative'],'Negative')
df.review.value_counts()
# Out:
# Neutral     8929
# Positive    6013
# Negative    5287
# Name: review, dtype: int64

# %%
df.isnull().sum()
# Out:
# statement    1
# review       0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# statement    0
# review       0
# dtype: int64

# %%
df.head()
# Out:
#                                            statement    review
# 0  Sai kha ya her kisi kay bus ki bat nhi hai lak...  Positive
# 1                                          sahi bt h  Positive
# 2                                        Kya bt hai,  Positive
# 3                                         Wah je wah  Positive
# 4                               Are wha kaya bat hai  Positive

# %%
from sklearn.utils import shuffle
from nltk import word_tokenize

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Kumar
# [nltk_data]     Shivam\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
stopwords=['ai', 'ayi', 'hy', 'hai', 'main', 'ki', 'tha', 'koi', 'ko', 'sy', 'woh', 'bhi', 'aur', 'wo', 'yeh', 'rha', 'hota', 'ho', 'ga', 'ka', 'le', 'lye', 'kr', 'kar', 'lye', 'liye', 'hotay', 'waisay', 'gya', 'gaya', 'kch', 'ab', 'thy', 'thay', 'houn', 'hain', 'han', 'to', 'is', 'hi', 'jo', 'kya', 'thi', 'se', 'pe', 'phr', 'wala', 'waisay', 'us', 'na', 'ny', 'hun', 'rha', 'raha', 'ja', 'rahay', 'abi', 'uski', 'ne', 'haan', 'acha', 'nai', 'sent', 'photo', 'you', 'kafi', 'gai', 'rhy', 'kuch', 'jata', 'aye', 'ya', 'dono', 'hoa', 'aese', 'de', 'wohi', 'jati', 'jb', 'krta', 'lg', 'rahi', 'hui', 'karna', 'krna', 'gi', 'hova', 'yehi', 'jana', 'jye', 'chal', 'mil', 'tu', 'hum', 'par', 'hay', 'kis', 'sb', 'gy', 'dain', 'krny', 'tou']

def clean(x):
    review_with_no_special_character = re.sub('[^a-zA-Z]',' ',str(x))
    review_in_lowercase = review_with_no_special_character.lower()
    review_in_tokens = word_tokenize(review_in_lowercase)
    review_with_no_stopwords = [word for word in review_in_tokens if not word in stopwords]
    review_in_sentence = ' '.join(review_with_no_stopwords)
    return review_in_sentence

df['statement_1'] = df['statement'].apply(lambda x:clean(x))

# %%
df.head()
# Out:
#                                            statement    review  \
# 0  Sai kha ya her kisi kay bus ki bat nhi hai lak...  Positive
# 1                                          sahi bt h  Positive
# 2                                        Kya bt hai,  Positive
# 3                                         Wah je wah  Positive
# 4                               Are wha kaya bat hai  Positive
#
#                                          statement_1
# 0  sai kha her kisi kay bus bat nhi lakin hal kal...
# 1                                          sahi bt h
# 2                                                 bt
# 3                                         wah je wah
# 4                                   are wha kaya bat

# %%
def cleaner(word):
      
      word = re.sub(r'\#\.', '', word)
      word = re.sub(r'\n', '', word)
      word = re.sub(r',', '', word)
      word = re.sub(r'\-', ' ', word)
      word = re.sub(r'\.', '', word)
      word = re.sub(r'\\', ' ', word)
      word = re.sub(r'\\x\.+', '', word)
      word = re.sub(r'\d', '', word)
      word = re.sub(r'^_.', '', word)
      word = re.sub(r'_', ' ', word)
      word = re.sub(r'^ ', '', word)
      word = re.sub(r' $', '', word)
      word = re.sub(r'\?', '', word)

      return word.lower()


cleaned1 = lambda x: cleaner(x)

# %% [markdown]
# # Apply first level cleaning
# import re
# import string
#
# #This function converts to lower-case, removes square bracket, removes numbers and punctuation
# def text_clean_1(text):
#     text = text.lower()
#     text = re.sub('\[.*?\]', '', text)
#     text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
#     text = re.sub('\w*\d\w*', '', text)
#     return text
#
# cleaned1 = lambda x: text_clean_1(x)

# %%
# Let's take a look at the updated text
df['cleaned_stat'] = pd.DataFrame(df.statement.apply(cleaned1))
df.head(10)
# Out:
#                                            statement    review  \
# 0  Sai kha ya her kisi kay bus ki bat nhi hai lak...  Positive
# 1                                          sahi bt h  Positive
# 2                                        Kya bt hai,  Positive
# 3                                         Wah je wah  Positive
# 4                               Are wha kaya bat hai  Positive
# 5                                 Wah kya baat likhi  Positive
# 6                              Wha Itni sari khubiya  Positive
# 7                                       Itni khubiya  Positive
# 8  Ya allah rehm farma hm sab pe or zalimo ko hid...  Positive
# 9  Please Everyone AllAh S.w.T ka naam hAmesha Ba...  Positive
#
#                                         cleaned_stat
# 0  sai kha ya her kisi kay bus ki bat nhi hai lak...
# 1                                          sahi bt h
# 2                                         kya bt hai
# 3                                         wah je wah
# ...

# %%
def hashing(word):
      
      word = re.sub(r'ain$', r'ein', word)
      word = re.sub(r'ai', r'ae', word)
      word = re.sub(r'ay$', r'e', word)
      word = re.sub(r'ey$', r'e', word)
      word = re.sub(r'ie$', r'y', word)
      word = re.sub(r'^es', r'is', word)
      word = re.sub(r'a+', r'a', word)
      word = re.sub(r'j+', r'j', word)
      word = re.sub(r'd+', r'd', word)
      word = re.sub(r'u', r'o', word)
      word = re.sub(r'o+', r'o', word)
      word = re.sub(r'ee+', r'i', word)
      if not re.match(r'ar', word):
            word = re.sub(r'ar', r'r', word)
            word = re.sub(r'iy+', r'i', word)
            word = re.sub(r'ih+', r'eh', word)
            word = re.sub(r's+', r's', word)
      if re.search(r'[rst]y', 'word') and word[-1] != 'y':
            word = re.sub(r'y', r'i', word)
      if re.search(r'[bcdefghijklmnopqrtuvwxyz]i', word):
            word = re.sub(r'i$', r'y', word)
      if re.search(r'[acefghijlmnoqrstuvwxyz]h', word):
            word = re.sub(r'h', '', word)
            word = re.sub(r'k', r'q', word)
      return word

cleaned2 = lambda x: hashing(x)

# %%
# Apply a second round of cleaning
def text_clean_2(text):
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    return text

cleaned2 = lambda x: text_clean_2(x)

# %%
# Let's take a look at the updated text
df['cleaned_stat2'] = pd.DataFrame(df.cleaned_stat.apply(cleaned2))
df.head(10)
# Out:
#                                            statement    review  \
# 0  Sai kha ya her kisi kay bus ki bat nhi hai lak...  Positive
# 1                                          sahi bt h  Positive
# 2                                        Kya bt hai,  Positive
# 3                                         Wah je wah  Positive
# 4                               Are wha kaya bat hai  Positive
# 5                                 Wah kya baat likhi  Positive
# 6                              Wha Itni sari khubiya  Positive
# 7                                       Itni khubiya  Positive
# 8  Ya allah rehm farma hm sab pe or zalimo ko hid...  Positive
# 9  Please Everyone AllAh S.w.T ka naam hAmesha Ba...  Positive
#
#                                         cleaned_stat  \
# 0  sai kha ya her kisi kay bus ki bat nhi hai lak...
# 1                                          sahi bt h
# 2                                         kya bt hai
# 3                                         wah je wah
# ...

# %%
df.to_csv("2.csv")

# %%
import re

text = u'soch dekho hamari kitni milti hai ðŸ˜‰ðŸ˜ '
print(text) # with emoji

def deEmojify(text):
    regrex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)
    return regrex_pattern.sub(r'',text)

print(deEmojify(text))
# Out:
# soch dekho hamari kitni milti hai ðŸ˜‰ðŸ˜
# soch dekho hamari kitni milti hai ðŸ˜‰ðŸ˜

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix,f1_score,accuracy_score

# %%
df_final = df[df['statement_1'] != '']
df.head()
# Out:
#                                            statement    review  \
# 0  Sai kha ya her kisi kay bus ki bat nhi hai lak...  Positive
# 1                                          sahi bt h  Positive
# 2                                        Kya bt hai,  Positive
# 3                                         Wah je wah  Positive
# 4                               Are wha kaya bat hai  Positive
#
#                                          statement_1
# 0  sai kha her kisi kay bus bat nhi lakin hal kal...
# 1                                          sahi bt h
# 2                                                 bt
# 3                                         wah je wah
# 4                                   are wha kaya bat

# %%
df[df['statement_1'] == '']
# Out:
#                      statement    review statement_1
# 339                        😁😁👍  Positive
# 3123                      Acha  Positive
# 3266                      Acha  Positive
# 3270                      Acha  Positive
# 3542                      Acha  Positive
# ...                        ...       ...         ...
# 14169                Ab to mil   Neutral
# 14312        Haan na tu hai na   Neutral
# 14373                 Kis liye   Neutral
# 17879  Jo  ka hai woh  ka hai    Neutral
# 19421            Haan wohi hai   Neutral
#
# [221 rows x 3 columns]

# %%
x= df_final.statement_1
y = df_final.review

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=40)

# %%
x_test.size
# Out:
# 4002

# %%
y_train.shape
# Out:
# (16005,)

# %%
tvec = TfidfVectorizer()
model = LogisticRegression(solver = "lbfgs")

# %%
X_train_vector = tvec.fit_transform(x_train)
X_test_vector = tvec.transform(x_test)

# %%
from sklearn.svm import SVC
classifier = SVC(kernel='linear', C=1.0, degree=3, random_state=0)
classifier.fit(X_train_vector, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_pred = classifier.predict(X_test_vector)

# %%
y_pred
# Out:
# array(['Negative', 'Neutral', 'Negative', ..., 'Neutral', 'Positive',
#        'Negative'], dtype=object)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6624187906046977
